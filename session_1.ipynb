# %%
num_1 = 5

num_2 = 10

answer = num_1 + num_2

answerstr = str(answer)

print("answer =", answer)
# Out:
# answer = 15

# %%
radius = 2
pi = 3.14
area = pi * (radius ** 2)

print("radius =", radius)
print("pi =", pi)
print("area =", area)
# Out:
# radius = 2
# pi = 3.14
# area = 12.56

# %%
name = "Rueben"
job = "Data Analyst"

name_job = f"Hi my name is {name} and I am a {job}."

phrase = "Hi my name is " + name + " and I am a " + job + "."

print(name_job)
print(phrase)
# Out:
# Hi my name is Rueben and I am a Data Analyst.
# Hi my name is Rueben and I am a Data Analyst.

# %%
phrase = name_job

phrase[::-1]

phrase[1::10]
# Out:
# 'iia y'

# %%
filename = "ssda903_list_1.csv"

short_fn = filename[8:-4]

short_fn
# Out:
# 'list_1'
