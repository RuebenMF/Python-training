# %%
# writing functions

# create a new function with def (short for define). Similar to for loops this is indent-sensitive - anything in the indentiation is included in the function. For example:
# def foo():
# inside the bracket i can specify an argument to feed the function later.
def fn(phrase):
	print(phrase)

fn(phrase="foo")
fn(phrase="bar")
# Out:
# foo
# bar

# %%
def fxy(x, y):
	print(f"The sum of {x} and {y} is {x + y}.")

fxy(x=7, y=9)
fxy(x=13, y=22)
fxy(x=69, y=420)

# you don't need to paramenter names to your arguments if you supply them in order.

fxy(1,2)

# you can give you parameters default values, so you don't need to define them later as an argument.
# def fxy(x=90, y=10)
# Out:
# The sum of 7 and 9 is 16.
# The sum of 13 and 22 is 35.
# The sum of 69 and 420 is 489.
# The sum of 1 and 2 is 3.

# %%
# Now it's your go. Write a function, with an appropriate name
# that divides one number by the other. Bonus points if you can make the function 
# always divide the largest of the two numbers by the smallest.
# Get the function to print the answer

def fnDiv(x, y):
	if x > y:
		print(f"{x} divided by {y} is {x / y}")
	else:
		print(f"{y} divided by {x} is {y / x}")

fnDiv(2,10)
# Out:
# 10 divided by 2 is 5.0

# %%
# Will LP's example
def div_xy(x, y):
	if x >= y:
		print(x/y)
	else:
		print(y/x)

div_xy(5, 10)
# Out:
# 2.0

# %%
variable_name = div_xy(30,12)

print(variable_name)
# Out:
# 2.5
# None

# %%
# You can define what is produced by the function using return
def sum_prod(num1, num2):
	sum = num1 + num2
	prod = num1 * num2

	return sum, prod

sum_ans, prod_ans = sum_prod(20, 3)

print(f"sum is {sum_ans}")
print(f"prod is {prod_ans}")
# Out:
# sum is 23
# prod is 60

# %%
# write a function that returns x / y and x - y, 
# always dividing the biggest by the smallest number 
# and always taking the smallest fromt he biggest

def minus_div(x, y):
	if x >= y:
		big = x
		small = y
	else:
		big = y
		small = x
	return big / small, big - small


minus_div(10,2)
# Out:
# (5.0, 8)

# %%
# here we apply a function to each row in a dataframe. this is much faster than creating a for-loop to do the same thing.

import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/data-to-insight/ERN-sessions/main/data/ChildCharacteristics.csv')

def ethnic_check(row):
	if row[0] == "W":
		return "Yes"
	else:
		return "No"

df['Is white'] = df['Ethnicity'].apply(ethnic_check)

df
# Out:
#      Unnamed: 0        LAchildID Ethnicity Is white
# 0             0  RND000215205141      WIRT      Yes
# 1             1  RND000824303014      WROM      Yes
# 2             2  RND000750143123      AOTH       No
# 3             3  RND000909164501      MWBC       No
# 4             4  RND000382171815      APKN       No
# ..          ...              ...       ...      ...
# 327         327  RND000112711501      WOTH      Yes
# 328         328  RND000513120794      WROM      Yes
# 329         329  RND000541643134      BCRB       No
# 330         330  RND000404939452      AIND       No
# 331         331  RND000589802835      WBRI      Yes
#
# [332 rows x 4 columns]

# %%
# 'https://raw.githubusercontent.com/data-to-insight/ERN-sessions/main/data/ChildIdentifiers.csv'
# write a function that calculates ages based on the data, and returns a new column in age range buckets
# 0-5, 6-11, 12-17, 18+

# import data
# write functions
# using conditionals
# chaqnge to date
# calculation on df columns
# making new column

from dateutil.relativedelta import relativedelta

df = pd.read_csv('https://raw.githubusercontent.com/data-to-insight/ERN-sessions/main/data/ChildIdentifiers.csv')

df['PersonBirthDate_dt'] = pd.to_datetime(df['PersonBirthDate'], format="%Y-%m-%d", errors='coerce')

df['Age'] = df['PersonBirthDate_dt'].apply(lambda row: relativedelta(pd.to_datetime('today'), row).years)

def age_bracket(row):
	if row[0] <= 5:
		return "0-5"
	elif row[0] <= 11:
		return "6-11"
	elif row[0] <= 17:
		return "12-17"
	elif row[0] >= 18:
		return "18+"

df["Age bracket"] = df['Age'].apply(age_bracket)

df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[79], line 30
#      27 	elif row[0] >= 18:
#      28 		return "18+"
# ---> 30 df["Age bracket"] = df['Age'].apply(age_bracket)
#      32 df
#
# File c:\Users\SBSITRM1\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\series.py:4943, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4808 def apply(
#    4809     self,
#    4810     func: AggFuncType,
#    (...)   4815     **kwargs,
#    4816 ) -> DataFrame | Series:
#    4817     """
#    4818     Invoke function on values of Series.
#    4819
#    (...)   4934     dtype: float64
#    4935     """
#    4936     return SeriesApply(
#    4937         self,
#    4938         func,
#    4939         convert_dtype=convert_dtype,
#    4940         by_row=by_row,
#    4941         args=args,
#    4942         kwargs=kwargs,
# -> 4943     ).apply()
#
# File c:\Users\SBSITRM1\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\apply.py:1422, in SeriesApply.apply(self)
#    1419     return self.apply_compat()
#    1421 # self.func is Callable
# -> 1422 return self.apply_standard()
#
# File c:\Users\SBSITRM1\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\apply.py:1502, in SeriesApply.apply_standard(self)
#    1496 # row-wise access
#    1497 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1498 # we need to give `na_action="ignore"` for categorical data.
#    1499 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1500 #  Categorical (GH51645).
#    1501 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1502 mapped = obj._map_values(
#    1503     mapper=curried, na_action=action, convert=self.convert_dtype
#    1504 )
#    1506 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1507     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1508     #  See also GH#25959 regarding EA support
#    1509     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\Users\SBSITRM1\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\base.py:925, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     922 if isinstance(arr, ExtensionArray):
#     923     return arr.map(mapper, na_action=na_action)
# --> 925 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File c:\Users\SBSITRM1\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File pandas/_libs/lib.pyx:2999, in pandas._libs.lib.map_infer()
#
# Cell In[79], line 21, in age_bracket(row)
#      20 def age_bracket(row):
# ---> 21 	if row[0] <= 5:
#      22 		return "0-5"
#      23 	elif row[0] <= 11:
#
# TypeError: 'int' object is not subscriptable

# %%
# Will's example

import numpy as np
# 'https://raw.githubusercontent.com/data-to-insight/ERN-sessions/main/data/ChildIdentifiers.csv'
# write a function that calculates ages based on the data, and returns a new column in age range buckets
# 0-5, 6-11, 12-17, 18+

# import data
# write functions
# using conditionals
# chaqnge to date
# calculation on df columns
# making new column

df = pd.read_csv('https://raw.githubusercontent.com/data-to-insight/ERN-sessions/main/data/ChildIdentifiers.csv')

def age_buckets(row):
    bday = pd.to_datetime(row, format="%Y-%m-%d")
    today = pd.to_datetime('today')

    # age = (today - bday)/pd.Timedelta(365.25, 'D')

    if bday + pd.DateOffset(years=6) > today:
        return '0-5 years'
    elif bday + pd.DateOffset(years=12) > today:
        return '6-11 years'
    elif bday + pd.DateOffset(years=18) > today:
        return '12-17 years'
    else:
        return '18+'
        
df['Age Bucket'] = df['PersonBirthDate'].apply(age_buckets)

df[['PersonBirthDate', 'Age Bucket']]
# Out:
#     PersonBirthDate   Age Bucket
# 0        2019-12-06   6-11 years
# 1        2011-04-27  12-17 years
# 2        2017-06-06   6-11 years
# 3        2014-10-03   6-11 years
# 4        2019-09-25   6-11 years
# ..              ...          ...
# 327      2010-07-07  12-17 years
# 328      2018-08-14   6-11 years
# 329      2021-12-09    0-5 years
# 330      2013-07-23  12-17 years
# 331      2021-10-25    0-5 years
#
# [332 rows x 2 columns]

# %%
# Additional assignments

https://github.com/data-to-insight/ERN-sessions/tree/cohort2T/assignments
